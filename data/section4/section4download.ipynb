# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import urllib.request
import numpy as np 
from os import listdir
import matplotlib.pyplot as plt
import cv2 as cv

# %%
col_names = ['group', 'subgroup', 'subgroup url', 'case ID', 'case description', 'img url', 'img name', 'img number', 'sex', 'age', 'body part']

data = pd.DataFrame(columns=col_names)

# %%
# read in file wth the images that are ultrasound images only
df_labels = pd.read_csv('HMSS_labels_rem.csv')

# %%
# make lists of all sections from the ultrasound only file
groups = df_labels['group'].unique().tolist()

# make list of all subgroups
subgroups = df_labels.groupby('group')['subgroup'].unique().apply(list)

# make list of all images per subgroup
imgs = df_labels['img name'].tolist()

# %%
# handle request and return as parsed HTML
def request_data(url):
    """
    Request data from HMSS website and parse with beautifulsoup.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    return soup

# download images
def download_imgs(urllink, tgt_path, filename):
    # full path: tgt_path + filename
    full_tgt_path = os.path.join(tgt_path, filename)
    # download image to the folder path
    urllib.request.urlretrieve(urllink, full_tgt_path)
    print('{} saved to {}.'.format(filename, full_tgt_path))

# %%
"""
Scraping the data from HMSS website for section 4 (4.1-4.5) 
"""

base_url = 'https://www.ultrasoundcases.info/'
INIT_URL = "https://www.ultrasoundcases.info/cases/head-and-neck/"
init_soup = request_data(INIT_URL)
first_level = init_soup.find_all("div", {"class": "candidate-filter"})
tgt_path = 'MedAI-MAE/data/imgs'
# make sure file directory exists
if not os.path.exists(tgt_path):
    os.makedirs(tgt_path)

img_num = 0 # number images starting from 0
# go through all first level categories (first level = body system (EX. 4 Head and Neck))
for item_l1 in first_level:
    # get the title from h4>a
    item_l1_title = item_l1.find("h4").find("a").text
    # only fetch section 4 items
    if (item_l1_title != 'Head and Neck'):
        continue
    
    print('Fetching', item_l1_title)
    
    # get the second level categories
    second_level = item_l1.find("ul").find_all("li")
    
    # iterate through each item in the second level (second level = group of body system (EX. 4.1 Thyroid Gland))
    for item_l2 in second_level:
        item_l2_title = item_l2.find("a").text
        item_l2_url_title = item_l2.find("a")['href']
        item_l2_id = item_l2.find("a")["data-id"] 

        # check if the group title is in the ultrasound only file
        if item_l2_title not in groups:
            continue # go to the next group

        # get the subgroups for this group
        l2_subgroups = subgroups[item_l2_title]

        print("Fetching", item_l2_title, item_l2_id)

        third_level = requests.get(
            "https://www.ultrasoundcases.info/api/cases/list/" + str(item_l2_id)
        ).json()
        
        # iterate through each item in the third level (third level = subgroup of group (EX. 4.1.1 Thyroid Congenital Abnormalities))
        for item_l3 in third_level: 
            item_l3_title = item_l3["title"]
            item_l3_urltitle = item_l3["urltitle"]
            item_l3_id = item_l3["id"]

            # check if subgroup is in the ultrasound only file
            if item_l3_title not in l2_subgroups:
                continue # go to the next subgroup

            print("Fetching", item_l3_title, item_l3_id)

            fourth_level = requests.post(
                "https://www.ultrasoundcases.info/api/cases/list/" +  str(item_l3_id) + '/',
                data={"type": "subsubcat"}
            ).json()

            # iterate through each item in the fourth level (fourth level = specific cases of subgroup (EX. Hypoplasia of the left thyroid lobe))
            for item_l4 in fourth_level:
                item_l4_id = item_l4['id']
                item_l4_title = item_l4['title']
                item_l4_subtitle = item_l4['subtitle']
                item_l4_thumb = item_l4['thumb']
                item_l4_urltitle = item_l4['urltitle']

                print("Fetching", item_l4_title, item_l4_id, item_l4_urltitle)

                item_l5_soup = request_data(
                    "https://www.ultrasoundcases.info/{}/".format(item_l4_urltitle)
                )

                # img information
                fifth_level = item_l5_soup.find("div", {"class": "portfolio"})
                fifth_level = fifth_level.find_all("img")

                # patient details
                l5_details = item_l5_soup.find("div", {"class": "information"})
                l5_h4 = l5_details.find("h4")
                
                # check if details about case exist
                if(l5_h4.text == 'Details'):
                    l5_patient_info = l5_details.find_all("li")
                    for i, li in enumerate(l5_patient_info):
                        details = ''.join(li.find_all(string=True, recursive=False)).strip()
                        if i == 0:
                            l5_sex = details
                        if i == 1:
                            l5_age = details
                        if i == 2:
                            l5_body_part = details
                else:
                    l5_sex = np.nan
                    l5_age = np.nan
                    l5_body_part = np.nan
                    

                # iterate through each item in the case level (fifth level = image details for the specific case)
                for item_l5 in fifth_level:  # case level

                    item_l5_img_url_src = item_l5["src"]
                    item_l5_img_url = "https://www.ultrasoundcases.info" + item_l5_img_url_src

                    # get image name
                    img_name = item_l5_img_url.split('/')
                    item_l5_img_name = img_name[-1]

                    # check if image is in the ultrasound images only file
                    if item_l5_img_name not in imgs:
                        continue # go to the next image

                    img_soup = request_data(
                        item_l5_img_url
                    )

                    print("Fetching", item_l5_img_url)

                    # prep data for data frame
                    item_l3_url = base_url + item_l2_url_title + item_l3_urltitle

                    # img number
                    img_num_name = f"{img_num:04d}"

                    # create row for dataframe
                    data.loc[len(data.index)] = [item_l2_title, item_l3_title, item_l3_url, item_l4_id, item_l4_subtitle, item_l5_img_url, item_l5_img_name, img_num_name, l5_sex, l5_age, l5_body_part]

                    # download images here
                    #download_imgs(item_l5_img_url, tgt_path, item_l5_img_name)

                    # add one to the image number
                    img_num += 1
# Out:
# Fetching Head and Neck
# Fetching 4.1 Thyroid gland 94
# Fetching 4.1.2 Thyroid benign lesions 276
# Fetching Thyroid benign lesions 3428 thyroid-benign-lesions-7944
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71396-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71397-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71398-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71399-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71400-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71401-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71402-Afbeelding7.jpg
# Fetching Thyroid benign lesions 3417 thyroid-benign-lesions-6881
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54946-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54947-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54948-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54949-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54950-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54951-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54952-Afbeelding7.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54953-Afbeelding8.jpg
# Fetching Thyroid benign lesions 3422 thyroid-benign-lesions-7136
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57867-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57868-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57869-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57870-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57871-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57872-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57873-Afbeelding7.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57874-Afbeelding8.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57875-Afbeelding9.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57876-Afbeelding10.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57877-Afbeelding11.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/57878-Afbeelding12.jpg
# Fetching Thyroid benign lesions 3411 thyroid-benign-lesions-5677
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/41468-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/41469-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/41470-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads
jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1416.jpg
# Fetching Papillary thyroid carcinoma 3431 papillary-thyroid-carcinoma-259
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1417.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1418.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1419.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1420.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1421.jpg
# Fetching Papillary thyroid carcinoma 3439 papillary-thyroid-carcinoma-3169
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16804.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16805.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16843.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16844.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16845.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16846.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16847.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/16848.jpg
# Fetching Papillary thyroid carcinoma 3429 papillary-thyroid-carcinoma-256
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1404.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1405.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1406.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1407.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1408.jpg
# Fetching Papillary thyroid carcinoma 3438 papillary-thyroid-carcinoma-2894
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14728.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14729.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14730.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14731.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14732.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14733.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14734.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14735.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14736.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14737.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14738.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14739.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/14740.jpg
# Fetching Papillary thyroid carcinoma 3432 papillary-thyroid-carcinoma-260
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1422.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1423.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1424.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1425.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1426.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1427.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1428.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1429.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1430.jpg
# Fetching Papillary thyroid carcinoma 3461 papillary-thyroid-carcinoma-6809
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53992-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53993-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53994-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53995-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53996-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53997-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53998-Afbeelding7.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/53999-Afbeelding8.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54000-Afbeelding9.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54001-Afbeelding10.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54002-Afbeelding11.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54003-Afbeelding12.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54004-Afbeelding13.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54005-Afbeelding14.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54006-Afbeelding15.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/54007-Afbeelding16.jpg
# Fetching Papillary thyroid carcinoma 3433 papillary-thyroid-carcinoma-261
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1431.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1432.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1433.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/1434.jpg
# Fetching Papillary thyroid carcinoma 3440 papillary-thyroid-carcinoma-3225
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17269.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17270.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17271.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17272.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17273.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17274.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17275.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17276.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17277.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17278.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17279.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/17280.jpg
# Fetching Papillary thyroid carcinoma 3466 papillary-thyroid-carcinoma-7663
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64405-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64406-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64407-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64408-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64409-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64410-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64411-Afbeelding7.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64412-Afbeelding8.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64413-Afbeelding9.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64414-Afbeelding10.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64415-Afbeelding11.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64416-Afbeelding12.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64417-Afbeelding13.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64418-Afbeelding14.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64419-Afbeelding15.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/64420-Afbeelding16.jpg
# Fetching Anaplasic thyroid carcinoma 3450 anaplasic-thyroid-carcinoma-5264
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37464-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37465-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37466-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37467-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37468-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37469-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/37470-Afbeelding7.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 119
#     116 if item_l5_img_name not in imgs:
#     117     continue # go to the next image
# --> 119 img_soup = request_data(
#     120     item_l5_img_url
#     121 )
#     123 print("Fetching", item_l5_img_url)
#     125 # prep data for data frame
#
# Cell In[5], line 6, in request_data(url)
#       2 def request_data(url):
#       3     """
#       4     Request data from HMSS website and parse with beautifulsoup.
#       5     """
# ----> 6     response = requests.get(url)
#       7     soup = BeautifulSoup(response.text, "html.parser")
#       8     return soup
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~/anaconda3/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File ~/anaconda3/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df_labels.head(1)
# Out:
#                group                      subgroup  \
# 0  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
#
#                                         subgroup url  \
# 0  https://www.ultrasoundcases.info//cases/head-a...
#
#                                     case description  \
# 0  Thyroid lesion that biopsy proved to be a foll...
#
#                                              img url               img name  \
# 0  https://www.ultrasoundcases.info/clients/ultra...  71396-Afbeelding1.jpg
#
#       sex age body part   label dataset
# 0  Female  43   Thyroid  benign    HMSS

# %%
tgt_group = '4.1 Thyroid gland'
tgt_subgroup = '4.1.2 Thyroid benign lesions'
tgt_subgroupurl = 'https://www.ultrasoundcases.info//cases/head-and-neck/thyroid-gland/thyroid-benign-lesions'
tgt_casedescription = 'Thyroid lesion that biopsy proved to be a follicular proliferation'
tgt_imgurl = 'https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/71396-Afbeelding1.jpg'
tgt_imgname = '71396-Afbeelding1.jpg'

result_row = df_labels[(df_labels['group'] == tgt_group) & (df_labels['subgroup'] == tgt_subgroup) & (df_labels['subgroup url'] == tgt_subgroupurl) & (df_labels['case description'] == tgt_casedescription) & (df_labels['img url'] == tgt_imgurl) & (df_labels['img name'] == tgt_imgname)]

label = result_row['label']
print(label)
# Out:
# 0    benign
# Name: label, dtype: object

# %%
data
# Out:
#                group                      subgroup  \
# 0  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 1  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 2  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 3  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 4  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 5  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
# 6  4.1 Thyroid gland  4.1.2 Thyroid benign lesions
#
#                                         subgroup url  case ID  \
# 0  https://www.ultrasoundcases.info//cases/head-a...     3428
# 1  https://www.ultrasoundcases.info//cases/head-a...     3428
# 2  https://www.ultrasoundcases.info//cases/head-a...     3428
# 3  https://www.ultrasoundcases.info//cases/head-a...     3428
# 4  https://www.ultrasoundcases.info//cases/head-a...     3428
# 5  https://www.ultrasoundcases.info//cases/head-a...     3428
# 6  https://www.ultrasoundcases.info//cases/head-a...     3428
#
#                                     case description  \
# 0  Thyroid lesion that biopsy proved to be a foll...
# 1  Thyroid lesion that biopsy proved to be a foll...
# 2  Thyroid lesion that biopsy proved to be a foll...
# 3  Thyroid lesion that biopsy proved to be a foll...
# 4  Thyroid lesion that biopsy proved to be a foll...
# 5  Thyroid lesion that biopsy proved to be a foll...
# 6  Thyroid lesion that biopsy proved to be a foll...
#
#                                              img url               img name  \
# 0  https://www.ultrasoundcases.info/clients/ultra...  71396-Afbeelding1.jpg
# 1  https://www.ultrasoundcases.info/clients/ultra...  71397-Afbeelding2.jpg
# 2  https://www.ultrasoundcases.info/clients/ultra...  71398-Afbeelding3.jpg
# 3  https://www.ultrasoundcases.info/clients/ultra...  71399-Afbeelding4.jpg
# 4  https://www.ultrasoundcases.info/clients/ultra...  71400-Afbeelding5.jpg
# 5  https://www.ultrasoundcases.info/clients/ultra...  71401-Afbeelding6.jpg
# 6  https://www.ultrasoundcases.info/clients/ultra...  71402-Afbeelding7.jpg
#
#   img number     sex age body part
# 0       0000  Female  43   Thyroid
# 1       0001  Female  43   Thyroid
# 2       0002  Female  43   Thyroid
# 3       0003  Female  43   Thyroid
# 4       0004  Female  43   Thyroid
# 5       0005  Female  43   Thyroid
# 6       0006  Female  43   Thyroid

# %%
# write dataframe to csv file
#data.to_csv('section4.csv', index=False)
