# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import urllib.request
import numpy as np 
from os import listdir
import matplotlib.pyplot as plt
import cv2 as cv

# %%
#col_names = ['group', 'subgroup', 'subgroup url', 'case description', 'img url', 'img name', 'case id/cover img id', 'crop r1', 'crop r2', 'crop col1', 'crop col2', 'tumor type', 'Notes']
col_names = ['group', 'subgroup', 'subgroup url', 'case description', 'img url', 'img name', 'sex', 'age', 'body part']

data = pd.DataFrame(columns=col_names)

# %%
# handle request and return as parsed HTML
def request_data(url):
    """
    Request data from HMSS website and parse with beautifulsoup.
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    return soup

# download images
def download_imgs(urllink, tgt_path, filename):
    # full path: tgt_path + filename
    full_tgt_path = os.path.join(tgt_path, filename)
    # download image to the folder path
    urllib.request.urlretrieve(urllink, full_tgt_path)
    print('{} saved to {}.'.format(filename, full_tgt_path))

# %%
"""
Scraping the data from HMSS website for section 8 (8.1-8.4)
"""

base_url = 'https://www.ultrasoundcases.info/'
INIT_URL = "https://www.ultrasoundcases.info/cases/thorax/"
init_soup = request_data(INIT_URL)
first_level = init_soup.find_all("div", {"class": "candidate-filter"})
tgt_path = 'images'
# make sure file directory exists
if not os.path.exists(tgt_path):
    os.makedirs(tgt_path)

# go through all first level categories (first level = body system (EX. 8 Thorax))
for item_l1 in first_level:
    # get the title from h4>a
    item_l1_title = item_l1.find("h4").find("a").text
    # only fetch section 4 items
    if (item_l1_title != 'Thorax'):
        continue
    print('Fetching', item_l1_title)
    
    # get the second level categories
    second_level = item_l1.find("ul").find_all("li")
    
    # iterate through each item in the second level (second level = group of body system (EX. 8.1 Pulmonary pathology))
    for item_l2 in second_level:
        item_l2_title = item_l2.find("a").text
        item_l2_url_title = item_l2.find("a")['href']
        item_l2_id = item_l2.find("a")["data-id"] 

        print("Fetching", item_l2_title, item_l2_id)

        third_level = requests.get(
            "https://www.ultrasoundcases.info/api/cases/list/" + str(item_l2_id)
        ).json()
        
        # iterate through each item in the third level (third level = subgroup of group (EX. 8.1.1 Pneumonia and air space consolidation))
        for item_l3 in third_level: 
            item_l3_title = item_l3["title"]
            item_l3_urltitle = item_l3["urltitle"]
            item_l3_id = item_l3["id"]

            print("Fetching", item_l3_title, item_l3_id)

            fourth_level = requests.post(
                "https://www.ultrasoundcases.info/api/cases/list/" +  str(item_l3_id) + '/',
                data={"type": "subsubcat"}
            ).json()

            # iterate through each item in the fourth level (fourth level = specific cases of subgroup (EX. Pneumonia and air space consolidation))
            for item_l4 in fourth_level:
                item_l4_id = item_l4['id']
                item_l4_title = item_l4['title']
                item_l4_subtitle = item_l4['subtitle']
                item_l4_thumb = item_l4['thumb']
                item_l4_urltitle = item_l4['urltitle']

                print("Fetching", item_l4_title, item_l4_id, item_l4_urltitle)

                item_l5_soup = request_data(
                    "https://www.ultrasoundcases.info/{}/".format(item_l4_urltitle)
                )

                # img information
                fifth_level = item_l5_soup.find("div", {"class": "portfolio"})
                fifth_level = fifth_level.find_all("img")

                # patient details
                l5_details = item_l5_soup.find("div", {"class": "information"})
                l5_h4 = l5_details.find("h4")
                
                # check if details about case exist
                if(l5_h4.text == 'Details'):
                    l5_patient_info = l5_details.find_all("li")
                    for i, li in enumerate(l5_patient_info):
                        details = ''.join(li.find_all(string=True, recursive=False)).strip()
                        if i == 0:
                            l5_sex = details
                        if i == 1:
                            l5_age = details
                        if i == 2:
                            l5_body_part = details
                else:
                    l5_sex = np.nan
                    l5_age = np.nan
                    l5_body_part = np.nan
                    

                # iterate through each item in the case level (fifth level = image details for the specific case)
                for item_l5 in fifth_level:  # case level
                    item_l5_img_url_src = item_l5["src"]
                    item_l5_img_url = "https://www.ultrasoundcases.info" + item_l5_img_url_src

                    img_soup = request_data(
                        item_l5_img_url
                    )

                    print("Fetching", item_l5_img_url)

                    # prep data for dataframe
                    item_l3_url = base_url + item_l2_url_title + item_l3_urltitle
                    img_name = item_l5_img_url.split('/')
                    item_l5_img_name = img_name[-1]

                    # create row for dataframe
                    data.loc[len(data.index)] = [item_l2_title, item_l3_title, item_l3_url, item_l4_subtitle, item_l5_img_url, item_l5_img_name, l5_sex, l5_age, l5_body_part]

                    # download images here
                    # download_imgs(item_l5_img_url, tgt_path, item_l5_img_name)
# Out:
# Fetching Thorax
# Fetching 8.1 Pulmonary pathology 117
# Fetching 8.1.1 Pneumonia and air space consolidation 454
# Fetching COVID-19 Pneumonia 8295 covid19-pneumonia-0
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/videos/8295-case-1.6-ct.jpg?c=1
# Fetching COVID-19 Pneumonia 8296 covid19-pneumonia-2
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/8296-case-2---resize-3.jpg?c=1
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/8296-case-2---resize-3.jpg?c=1
# Fetching COVID-19 Pneumonia 8297 covid19-pneumonia-3
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/8297-case-3--2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/8297-case-3--2.jpg
# Fetching Pneumonia and air space consolidation 6843 pneumonia-and-air-space-consolidation-5358
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38382-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38383-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38384-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38385-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38386-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38387-Afbeelding6.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38388-Afbeelding7.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38389-Afbeelding8.jpg
# Fetching Pneumonia and air space consolidation 6842 pneumonia-and-air-space-consolidation-4127
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23829.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23830.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23831.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23832.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/27519-23833.jpg
# Fetching Pneumonia and air space consolidation 6832 pneumonia-and-air-space-consolidation-828
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4341.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4342.jpg
# Fetching Pneumonia and air space consolidation 6833 pneumonia-and-air-space-consolidation-829
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4343.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4344.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4345.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4346.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4347.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4348.jpg
# Fetching Pneumonia and air space consolidation 6834 pneumonia-and-air-space-consolidation-830
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4349.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4350.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4351.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4352.jpg
# Fetching Pneumonia and air space consolidation 6835 pneumonia-and-air-space-consolidation-831
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4355.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4356.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4357.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4358.jpg
# Fetching Pneumonia and air space consolidation 6836 pneumonia-and-air-space-consolidation-832
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4359.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4360.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4361.jpg
# Fetching Pneumonia and air space consolidation 6837 pneumonia-and-air-space-consolidation-833
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4362.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4363.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4364.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4365.jpg
# Fetching Pneumonia and air space consolidation 6841 pneumonia-and-air-space-consolidation-3016
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15668.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15669.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15670.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15671.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15682.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15683.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15684.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15685.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/15686.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4445.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4446.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4447.jpg
# Fetching 8.2.2 Benign and malignant pleural thickening 459
# Fetching Benign pleural thickening 6871 benign-pleural-thickening-3836
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21457.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21458.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21459.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21460.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21461.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21462.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21463.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/21464.jpg
# Fetching Benign pleural thickening 6863 benign-pleural-thickening-850
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4448.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4449.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4450.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4451.jpg
# Fetching Benign pleural thickening 6872 benign-pleural-thickening-4126
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23824.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23825.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23826.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23827.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/23828.jpg
# Fetching Malignant pleural thickening 6864 malignant-pleural-thickening-851
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4452.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4453.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4454.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4455.jpg
# Fetching Malignant pleural thickening 6865 malignant-pleural-thickening-852
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4456.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4457.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4458.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4459.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4460.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4461.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4462.jpg
# Fetching Malignant pleural thickening 6874 malignant-pleural-thickening-5318
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38018-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38019-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38020-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/38021-Afbeelding4.jpg
# Fetching Malignant pleural thickening 6866 malignant-pleural-thickening-853
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4463.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4464.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4465.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4466.jpg
# Fetching Malignant pleural thickening 6867 malignant-pleural-thickening-854
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4467.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4468.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4469.jpg
# Fetching Malignant pleural thickening 6868 malignant-pleural-thickening-855
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4470.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4471.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4472.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4473.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4474.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4475.jpg
# Fetching Malignant pleural thickening 6869 malignant-pleural-thickening-856
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4476.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4477.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4478.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4479.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4480.jpg
# Fetching Malignant pleural thickening 6870 malignant-pleural-thickening-857
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4481.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4482.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4483.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4484.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4485.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/4486.jpg
# Fetching Malignant pleural thickening 6873 malignant-pleural-thickening-4939
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34230-Afbeelding1.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34231-Afbeelding2.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34232-Afbeelding3.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34233-Afbeelding4.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34234-Afbeelding5.jpg
# Fetching https://www.ultrasoundcases.info/clients/ultrasoundcases/uploads/34235-Afbeelding6.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 95
#      92 item_l5_img_url_src = item_l5["src"]
#      93 item_l5_img_url = "https://www.ultrasoundcases.info" + item_l5_img_url_src
# ---> 95 img_soup = request_data(
#      96     item_l5_img_url
#      97 )
#      99 print("Fetching", item_l5_img_url)
#     101 # prep data for dataframe
#
# Cell In[3], line 6, in request_data(url)
#       2 def request_data(url):
#       3     """
#       4     Request data from HMSS website and parse with beautifulsoup.
#       5     """
# ----> 6     response = requests.get(url)
#       7     soup = BeautifulSoup(response.text, "html.parser")
#       8     return soup
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data
# Out:
#                        group                                       subgroup  \
# 0    8.1 Pulmonary pathology    8.1.1 Pneumonia and air space consolidation
# 1    8.1 Pulmonary pathology    8.1.1 Pneumonia and air space consolidation
# 2    8.1 Pulmonary pathology    8.1.1 Pneumonia and air space consolidation
# 3    8.1 Pulmonary pathology    8.1.1 Pneumonia and air space consolidation
# 4    8.1 Pulmonary pathology    8.1.1 Pneumonia and air space consolidation
# ..                       ...                                            ...
# 240        8.2 Pleural space  8.2.2 Benign and malignant pleural thickening
# 241        8.2 Pleural space  8.2.2 Benign and malignant pleural thickening
# 242        8.2 Pleural space  8.2.2 Benign and malignant pleural thickening
# 243        8.2 Pleural space  8.2.2 Benign and malignant pleural thickening
# 244        8.2 Pleural space  8.2.2 Benign and malignant pleural thickening
#
#                                           subgroup url  \
# 0    https://www.ultrasoundcases.info//cases/thorax...
# 1    https://www.ultrasoundcases.info//cases/thorax...
# 2    https://www.ultrasoundcases.info//cases/thorax...
# 3    https://www.ultrasoundcases.info//cases/thorax...
# 4    https://www.ultrasoundcases.info//cases/thorax...
# ..                                                 ...
# 240  https://www.ultrasoundcases.info//cases/thorax...
# 241  https://www.ultrasoundcases.info//cases/thorax...
# 242  https://www.ultrasoundcases.info//cases/thorax...
# 243  https://www.ultrasoundcases.info//cases/thorax...
# 244  https://www.ultrasoundcases.info//cases/thorax...
#
#                                       case description  \
# 0    Bilateral interstitial pneumonia and myocardit...
# 1    Bilateral interstitial pneumonia due to COVID-...
# 2    Bilateral interstitial pneumonia due to COVID-...
# 3    Bilateral interstitial pneumonia with posterio...
# 4    Bilateral interstitial pneumonia with posterio...
# ..                                                 ...
# 240  Carcinomatous pleuritis with pleural nodules p...
# 241  Carcinomatous pleuritis with pleural nodules p...
# 242  Carcinomatous pleuritis with pleural nodules p...
# 243  Carcinomatous pleuritis with pleural nodules p...
# 244  Carcinomatous pleuritis with pleural nodules p...
#
#                                                img url  \
# 0    https://www.ultrasoundcases.info/clients/ultra...
# 1    https://www.ultrasoundcases.info/clients/ultra...
# 2    https://www.ultrasoundcases.info/clients/ultra...
# 3    https://www.ultrasoundcases.info/clients/ultra...
# 4    https://www.ultrasoundcases.info/clients/ultra...
# ..                                                 ...
# 240  https://www.ultrasoundcases.info/clients/ultra...
# 241  https://www.ultrasoundcases.info/clients/ultra...
# 242  https://www.ultrasoundcases.info/clients/ultra...
# 243  https://www.ultrasoundcases.info/clients/ultra...
# 244  https://www.ultrasoundcases.info/clients/ultra...
#
#                            img name     sex age      body part
# 0          8295-case-1.6-ct.jpg?c=1    Male  77           Lung
# 1    8296-case-2---resize-3.jpg?c=1  Female  82           Lung
# 2    8296-case-2---resize-3.jpg?c=1  Female  82           Lung
# 3                8297-case-3--2.jpg    Male  50           Lung
# 4                8297-case-3--2.jpg    Male  50           Lung
# ..                              ...     ...  ..            ...
# 240           34231-Afbeelding2.jpg  Female  77  Pleural space
# 241           34232-Afbeelding3.jpg  Female  77  Pleural space
# 242           34233-Afbeelding4.jpg  Female  77  Pleural space
# 243           34234-Afbeelding5.jpg  Female  77  Pleural space
# 244           34235-Afbeelding6.jpg  Female  77  Pleural space
#
# [245 rows x 9 columns]

# %%
# write dataframe to csv file
data.to_csv('section8.csv', index=False)
